# %% [markdown]
# # Linked List Constructor

# %%
from Constructor.LinkedList import LinkedList, Node
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Constructor.LinkedList import LinkedList, Node
#
# ImportError: cannot import name 'LinkedList' from 'Constructor.LinkedList' (/Users/pawanpahune/DSA_Python/Constructor/LinkedList.py)

# %%
# Out:
# '/Users/pawanpahune/DSA_Python'

# %% [markdown]
# # Hash Tables Constructor

# %%
from Constructor.HashTables import HashTables

# %%
my_hash_table = HashTables(7)
my_hash_table.set_item("bolt", 24)
my_hash_table.set_item("nail", 12)
my_hash_table.set_item("screwdriver", 36)
my_hash_table.set_item("hammer", 18)
my_hash_table.print_table()
# Out:
# 0 :  [['nail', 12]]
# 1 :  [['hammer', 18]]
# 2 :  None
# 3 :  None
# 4 :  None
# 5 :  [['bolt', 24]]
# 6 :  [['screwdriver', 36]]

# %%
my_hash_table.set_item("wrench", 30)
my_hash_table.set_item("drill", 42)
my_hash_table.get_item("screwdriver")
# Out:
# 36

# %%
print(my_hash_table.get_item("Apple"))
# Out:
# None

# %%
print(my_hash_table.keys())
# Out:
# ['nail', 'hammer', 'bolt', 'screwdriver', 'wrench', 'drill']
